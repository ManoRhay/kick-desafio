# %%
import pandas as pd
import matplotlib.pyplot as plt

leitor_pda = pd.read_csv('PDA_PNME_2017_2018_2019.csv', sep= ';', encoding='latin-1')

print(leitor_pda.head()) 
print(leitor_pda.columns)

o_municipio = leitor_pda['NOME_MUNICIPIO'].value_counts().nlargest(25)

print(o_municipio)
o_municipio.plot(kind='bar')
plt.xlabel('NOME_MUNICÍPIO')
# Out:
# C:\Users\rhaya\AppData\Local\Temp\ipykernel_18496\2224203965.py:4: DtypeWarning: Columns (0,1,2,3,5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   leitor_pda = pd.read_csv('PDA_PNME_2017_2018_2019.csv', sep= ';', encoding='latin-1')
#   ï»¿NOME_UF NOME_MUNICIPIO ESFERA_GOV_ESCOLA LOCALIZACAO_ESCOLA  INEP_ESCOLA  \
# 0         RO    PORTO VELHO          ESTADUAL             Urbana   11000708.0
# 1         RO    PORTO VELHO         MUNICIPAL              Rural   11000864.0
# 2         RO    PORTO VELHO          ESTADUAL             Urbana   11001160.0
# 3         RO    PORTO VELHO          ESTADUAL             Urbana   11001496.0
# 4         RO    PORTO VELHO          ESTADUAL             Urbana   11002255.0
#
#                          NOME_ESCOLA  QUANT_ALUNADO  VALOR_RECEBIDO
# 0  EEEFM CAP CLAUDIO MANOEL DA COSTA           60.0     R$ 4.120,00
# 1       EMEF DEIGMAR MORAES DE SOUZA          200.0    R$ 54.840,00
# ...
